# %% [markdown]
# # Las alternativas a Jupyter

# %% [markdown]
# - [Google Collab](https://colab.research.google.com/)
#
# - [Kaggle Notebooks](https://www.kaggle.com/notebooks)
#
# - [Aws virtual services](https://www.google.com/aclk?sa=L&ai=DChcSEwjJm5bht4fsAhWWgpEKHTnDDx8YABAAGgJjZQ&sig=AOD64_0oQXMPSWbJVuphaeDxmj_3EzuYKQ&q&adurl&ved=2ahUKEwidoI7ht4fsAhUxGbkGHTXuAbsQ0Qx6BAgUEAE)
#
# - [Jupyter notebook on raspberry](https://github.com/kleinee/jns)
#
# Ejemplos:
#
# 1) [Ejemplo collab](https://colab.research.google.com/notebooks/welcome.ipynb?hl=es_US)
#
# 2) [Ejemplo Kaggle 1](https://www.kaggle.com/ericzepeda/master-effect-imgtocaption)
#
# 3) [Ejemplo Kaggle 2](https://www.kaggle.com/ericzepeda/taller-2)

# %% [markdown]
# # La importancia de las buenas prácticas

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# # Numpy: Una librería más que universal
#
# Numpy es una librería de algebra lineal para python. Lo bueno de esta es que se utiliza en compañia de las siguientes librerias:
#
# 1) Pandas
#
# 2) Sklearn
#
# 3) Tensorflow
#
# 4) Pytorch
#
# 5) Matplotlib
#
# 6) Keras
#
# 7) Pyomo
#
# ### Sus tiempos de ejecucion de carga de datos:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Referencias
#
# - [Let’s talk about NumPy — for Data Science Beginners](https://towardsdatascience.com/lets-talk-about-numpy-for-datascience-beginners-b8088722309f)
#
# - [5 reasons to use numpy](https://insights.dice.com/2016/09/01/5-reasons-know-numpy/)
#
# - [Why numpy is faster](https://www.geeksforgeeks.org/why-numpy-is-faster-in-python/)
#
# - [Numpy tutorial for beginners](https://www.kaggle.com/legendadnan/numpy-tutorial-for-beginners-data-science)
#
# - [Matlab vs python](https://rlhick.people.wm.edu/posts/comparing-the-speed-of-matlab-versus-pythonnumpy-partii.html)
#
# - [Clean Code](https://youtu.be/uQfm6YaJTJI)
#
# - [Clean Coder review](https://youtu.be/IxbhAsDDbmI)
#
# - [Github best practices](https://www.datree.io/resources/github-best-practices)
#
# - [Awesome Guidelines](https://github.com/Kristories/awesome-guidelines)
